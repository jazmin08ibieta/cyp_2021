# %% [markdown]
# <a href="https://colab.research.google.com/github/jazmin08ibieta/cyp_2021/blob/main/3_Diciembre_CyP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejemplo 1

for i in [1,2,3,5]:
  print(f"El elemento:{i}")
# Out:
# El elemento:1
# El elemento:2
# El elemento:3
# El elemento:5

# %%
coleccion=[1,2,3,4,5]
for i in coleccion:
  print(f"El elemento:{i}")
# Out:
# El elemento:1
# El elemento:2
# El elemento:3
# El elemento:4
# El elemento:5

# %%
#Ejemplo 2

coleccion={"Mario": 20, "Mariana": 19, "Yesica": 14, "Luis": 18}

for i in coleccion:
  print(f"Elemento: {i}")
# Out:
# Elemento: Mario
# Elemento: Mariana
# Elemento: Yesica
# Elemento: Luis

# %%
coleccion={"Mario": 20, "Mariana": 19, "Yesica": 14, "Luis": 18}

for i in coleccion:
  print(f"{coleccion[i]}")
# Out:
# 20
# 19
# 14
# 18

# %%
coleccion={"Mario": 20, "Mariana": 19, "Yesica": 14, "Luis": 18}

for i in coleccion:
  print(f"{i} -->{coleccion[i]}")
# Out:
# Mario -->20
# Mariana -->19
# Yesica -->14
# Luis -->18

# %%
coleccion={"Mario": 20, "Mariana": 19, "Yesica": 14, "Luis": 18}

for clave, valor in coleccion.items():
  print(f"{clave} -> {valor}")
# Out:
# Mario -> 20
# Mariana -> 19
# Yesica -> 14
# Luis -> 18

# %%
#Ejemplo 3

email=False
for i in"ariel@unam.mx":
  if(i=="@"):
   email=True
if email== True:
  print("El email es correcto")

else:
  print("El correo no es correcto")

# %%
email=False
miEmail=input("Introduce tu correo electronico: ")
for i in"ariel@unam.mx":
  if(i=="@"):
   email=True
if email:
  print("El email es correcto")

else:
  print("El correo no es correcto")
# Out:
# Introduce tu correo electronicoanita@gmail.com
# El email es correcto

# %%
#For Range

for i in range (5):
  print("Hola")
# Out:
# Hola
# Hola
# Hola
# Hola
# Hola

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (10):
  print(f"valor de la variable{i}")
# Out:
# valor de la variable0
# valor de la variable1
# valor de la variable2
# valor de la variable3
# valor de la variable4
# valor de la variable5
# valor de la variable6
# valor de la variable7
# valor de la variable8
# valor de la variable9

# %%
#While ejemplos

#Ejemplo 1

i=1
while i<=10:
 print("Ejecucion"+ str(i))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# ...

# %%
i=1

while i <= 10:
  print("ejecucion"+str(i))

  i=i+1 #contador, incrementa en 1 la variable
# Out:
# ejecucion1
# ejecucion2
# ejecucion3
# ejecucion4
# ejecucion5
# ejecucion6
# ejecucion7
# ejecucion8
# ejecucion9
# ejecucion10

# %%
edad=int(input("Ingresa tu edad: "))
while edad <0:
  print("Has introducido una edad negativa, Intentalo de nuevo")
  edad=int(input("Introduce tu edad: "))

print("Gracias por participar. Puedes pasar")
print("Edad del aspirante" + str (edad))
# Out:
# Ingresa tu edad: -9
# Has introducido una edad negativa, Intentalo de nuevo
# Introduce tu edad: -4
# Has introducido una edad negativa, Intentalo de nuevo
# Introduce tu edad: 8
# Gracias por participar. Puedes pasar
# Edad del aspirante8

# %%
edad=int(input("Ingresa tu edad: "))
while edad <10 or edad >=100:
  print("Has introducido una edad negativa, Intentalo de nuevo")
  edad=int(input("Introduce tu edad: "))

print("Gracias por participar. Puedes pasar")
print("Edad del aspirante" + str (edad))
# Out:
# Ingresa tu edad: 98
# Gracias por participar. Puedes pasar
# Edad del aspirante98
