# %% [markdown]
# <a href="https://colab.research.google.com/github/jazmin08ibieta/cyp_2021/blob/main/Tarea_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661")
print("\u2661                                                                                                                             \u2661")
print("\u2661        \u2661\u2661\u2661\u2661\u2661\u2661\u2661\u2661\u2661               \u2661                   \u2661\u2661\u2661\u2661\u2661\u2661\u2661\u2661\u2661\u2661        \u2661        \u2661         \u2661      \u2661           \u2661          \u2661")
print("\u2661            \u2661                   \u2661   \u2661                           \u2661         \u2661  \u2661  \u2661  \u2661         \u2661     \u2661  \u2661        \u2661          \u2661")
print("\u2661            \u2661                 \u2661        \u2661                     \u2661            \u2661    \u2661   \u2661         \u2661     \u2661    \u2661      \u2661          \u2661")
print("\u2661            \u2661               \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661                \u2661               \u2661        \u2661         \u2661     \u2661      \u2661    \u2661          \u2661")
print("\u2661            \u2661             \u2661                \u2661           \u2661                  \u2661        \u2661         \u2661     \u2661        \u2661  \u2661          \u2661")
print("\u2661            \u2661           \u2661                    \u2661      \u2661\u2661\u2661\u2661\u2661\u2661\u2661\u2661\u2661\u2661\u2661         \u2661        \u2661        \u2661      \u2661         \u2661 \u2661          \u2661")
print("\u2661            \u2661         \u2661                        \u2661                           \u2661        \u2661        \u2661      \u2661           \u2661          \u2661")
print("\u2661      \u2661\u2661\u2661\u2661\u2661\u2661                                                                                                                \u2661                                            ")
print("\u2661                                                                                                                             \u2661")
print("\u2661                                                                                                                             \u2661")
print("\u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661\u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661 \u2661")
# Out:
# ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡ ♡
# ♡                                                                                                                             ♡
# ♡        ♡♡♡♡♡♡♡♡♡               ♡                   ♡♡♡♡♡♡♡♡♡♡        ♡        ♡         ♡      ♡           ♡          ♡
# ♡            ♡                   ♡   ♡                           ♡         ♡  ♡  ♡  ♡         ♡     ♡  ♡        ♡          ♡
# ♡            ♡                 ♡        ♡                     ♡            ♡    ♡   ♡         ♡     ♡    ♡      ♡          ♡
# ♡            ♡               ♡ ♡ ♡ ♡ ♡ ♡ ♡                ♡               ♡        ♡         ♡     ♡      ♡    ♡          ♡
# ♡            ♡             ♡                ♡           ♡                  ♡        ♡         ♡     ♡        ♡  ♡          ♡
# ...
